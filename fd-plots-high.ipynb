# %%
# %pip install wheel
# %pip install pandas

# %%
import pandas as pd
from manim import *

# %%
# %%manim -qh -v WARNING Spiral15High
#
# # config.background_color = WHITE
# df = pd.read_csv('spiral_15_High.csv')
# missn_time = df.get('missn_time').to_list()
# roll_deg = df.get('_roll__deg').to_list()
#
# # plt.plot(missn_time, roll_deg)
# # plt.show()
#
#
# class Spiral15High(Scene):
#     def construct(self):
#         ax = Axes(
#
#             x_range = [min(missn_time), max(missn_time)+10,5],
#             y_range = [min(roll_deg), max(roll_deg), 5],
#             axis_config={'include_numbers': True,
#                          'tip_shape': StealthTip,
#                         #  'color': BLACK
#                         },
#             y_length = 7,
#         )
#
#         title = Title(r"Spiral Mode $15\deg$: High Altitude")
#         self.add(title)
#         self.wait(1)
#
#         x_label = ax.get_x_axis_label(
#             Tex("Mission Time").scale(0.7))
#         y_label = ax.get_y_axis_label(
#             Tex("Roll angle").scale(0.7))
#
#         self.play(Create(x_label), Create(y_label))
#         # self.wait(1)
#         self.play(Write(ax))
#         # self.wait(1)
#
#         plot = ax.plot_line_graph(missn_time, roll_deg, add_vertex_dots=False, line_color=WHITE)
#         self.play(Write(plot), run_time=5)
#         # self.wait(1)
#
#         x_value = roll_deg.index(max(roll_deg))
#         print(x_value)
#         point = ax.c2p(missn_time[x_value], max(roll_deg))
#         label = Tex("Max. Amplitude")
#         # frequency =Tex(r"Frequence = $$")
#         dot = Dot(point)# Create a label
#         label.next_to(dot, DR, buff=SMALL_BUFF)  # Position the label relative to the dot
#         self.play(Create(dot), Create(label))
#         self.wait(2)

# %%
# %%manim -qh -v WARNING Spiral30High
#
# # config.background_color = WHITE
# df = pd.read_csv('spiral_30_high.csv')
# missn_time = df.get('missn_time').to_list()
# roll_deg = df.get('_roll__deg').to_list()
#
# # plt.plot(missn_time, roll_deg)
# # plt.show()
#
# class Spiral30High(Scene):
#     def construct(self):
#         ax = Axes(
#             x_range = [min(missn_time), max(missn_time)+10, 10],
#             y_range = [min(roll_deg), max(roll_deg), 10],
#             axis_config={'include_numbers': True,
#                          'tip_shape': StealthTip,
#                         #  'color': BLACK
#                         },
#             y_length = 7,
#         )
#
#         title = Title(r"Spiral Mode $30\deg$: High Altitude", font_size=30, include_underline=False)
#         self.add(title)
#         self.wait(1)
#
#         x_label = ax.get_x_axis_label(
#             Tex("Mission Time").scale(0.7))
#         y_label = ax.get_y_axis_label(
#             Tex("Roll angle").scale(0.7))
#
#         self.play(Create(x_label), Create(y_label))
#         # self.wait(1)
#         self.play(Write(ax))
#         # self.wait(1)
#
#         plot = ax.plot_line_graph(missn_time, roll_deg, add_vertex_dots=False, line_color=WHITE)
#         self.play(Write(plot), run_time=5)
#         # self.wait(1)
#
#         x_value = roll_deg.index(max(roll_deg))
#         print(x_value)
#         point = ax.c2p(missn_time[x_value], max(roll_deg))
#         label = Tex("Max. Amplitude")
#         dot = Dot(point)# Create a label
#         label.next_to(dot, DR, buff=SMALL_BUFF)  # Position the label relative to the dot
#         self.play(Create(dot), Create(label))
#
#         self.wait(2)

# %%
# %%manim -qh -v WARNING Spiral45High
#
# # config.background_color = WHITE
# df = pd.read_csv('spiral_45_High.csv')
# missn_time = df.get('missn_time').to_list()
# roll_deg = df.get('_roll__deg').to_list()
#
# # plt.plot(missn_time, roll_deg)
# # plt.show()
#
# class Spiral45High(Scene):
#     def construct(self):
#         ax = Axes(
#             x_range = [min(missn_time), max(missn_time)+10, 10],
#             y_range = [min(roll_deg), max(roll_deg), 10],
#             axis_config={'include_numbers': True,
#                          'tip_shape': StealthTip,
#                         #  'color': BLACK
#                         },
#             y_length = 7,
#         )
#
#         x_label = ax.get_x_axis_label(
#             Tex("Mission Time").scale(0.7))
#         y_label = ax.get_y_axis_label(
#             Tex("Roll angle").scale(0.7))
#
#         title = Title(r"Spiral Mode $45\deg$: High Altitude")
#         self.add(title)
#         self.wait(1)
#
#         self.play(Create(x_label), Create(y_label))
#         # self.wait(1)
#         self.play(Write(ax))
#         # self.wait(1)
#
#         plot = ax.plot_line_graph(missn_time, roll_deg, add_vertex_dots=False, line_color=WHITE)
#         self.play(Write(plot), run_time=5)
#         # self.wait(1)
#
#         x_value = roll_deg.index(max(roll_deg))
#         print(x_value)
#         point = ax.c2p(missn_time[x_value], max(roll_deg))
#         label = Tex("Max. Amplitude")
#         dot = Dot(point)# Create a label
#         label.next_to(dot, DR, buff=SMALL_BUFF)  # Position the label relative to the dot
#         self.play(Create(dot), Create(label))
#
#         self.wait(2)

# %%
# %%manim -qh -v WARNING SPHigh
#
# # config.background_color = WHITE
# df = pd.read_csv('shortperiod_High.csv')
# missn_time = df.get('missn_time').to_list()
# roll_deg = df.get('_roll__deg').to_list()
#
# # plt.plot(missn_time, roll_deg)
# # plt.show()
#
# class SPHigh(Scene):
#     def construct(self):
#         ax = Axes(
#             x_range = [min(missn_time), max(missn_time)+2, 1],
#             y_range = [min(roll_deg), max(roll_deg), 10],
#             axis_config={'include_numbers': True,
#                          'tip_shape': StealthTip,
#                         #  'color': BLACK
#                         },
#             y_length = 7,
#         )
#
#         title = Title(f"Short Period Mode: High Altitude")
#         self.add(title)
#         self.wait(1)
#
#         x_label = ax.get_x_axis_label(
#             Tex("Mission Time").scale(0.7))
#         y_label = ax.get_y_axis_label(
#             Tex("Roll angle").scale(0.7))
#
#         self.play(Create(x_label), Create(y_label))
#         # self.wait(1)
#         self.play(Write(ax))
#         # self.wait(1)
#
#         plot = ax.plot_line_graph(missn_time, roll_deg, add_vertex_dots=False, line_color=WHITE)
#         self.play(Write(plot), run_time=5)
#         # self.wait(1)
#
#         x_value = roll_deg.index(max(roll_deg))
#         print(x_value)
#         point = ax.c2p(missn_time[x_value], max(roll_deg))
#         label = Tex("Max. Amplitude")
#         dot = Dot(point)# Create a label
#         label.next_to(dot, DR, buff=SMALL_BUFF)  # Position the label relative to the dot
#         self.play(Create(dot), Create(label))
#
#         self.wait(2)
#
#         frequency =Tex(f"Frequency = 0.64528.53708 Hz")
#         dampingRatio =Tex(f"Damping Ratio = 0.1 Hz")
#         subsidenceRatio =Tex(f"Subsidence Ratio = 0.53180 Hz")
#
#         self.add(frequency, dampingRatio, subsidenceRatio)

# %%
# %%manim -qh -v WARNING DRHigh
#
# # config.background_color = WHITE
# df = pd.read_csv('DR_High.csv')
# missn_time = df.get('missn_time').to_list()
# roll_deg = df.get('_beta__deg').to_list()
#
# # plt.plot(missn_time, roll_deg)
# # plt.show()
#
# class DRHigh(Scene):
#     def construct(self):
#         ax = Axes(
#             x_range = [min(missn_time), max(missn_time)+2, 1],
#             y_range = [min(roll_deg), max(roll_deg), 10],
#             axis_config={'include_numbers': True,
#                          'tip_shape': StealthTip,
#                         #  'color': BLACK
#                         },
#             y_length = 7,
#         )
#
#         title = Title(f"Dutch Roll Mode: High Altitude")
#         self.add(title)
#         self.wait(1)
#
#         x_label = ax.get_x_axis_label(
#             Tex("Mission Time").scale(0.7))
#         y_label = ax.get_y_axis_label(
#             Tex(r"$\beta$ angle").scale(0.7))
#
#         self.play(Create(x_label), Create(y_label))
#         # self.wait(1)
#         self.play(Write(ax))
#         # self.wait(1)
#
#         plot = ax.plot_line_graph(missn_time, roll_deg, add_vertex_dots=False, line_color=WHITE)
#         self.play(Write(plot), run_time=5)
#         # self.wait(1)
#
#         x_value = roll_deg.index(max(roll_deg))
#         print(x_value)
#         point = ax.c2p(missn_time[x_value], max(roll_deg))
#         label = Tex("Max. Amplitude")
#         dot = Dot(point)# Create a label
#         label.next_to(dot, DR, buff=SMALL_BUFF)  # Position the label relative to the dot
#         self.play(Create(dot), Create(label))
#
#         self.wait(2)
#
#         frequency =Tex(f"Frequency = 0.66099 Hz")
#         # dampingRatio =Tex(f"Damping Ratio = 0.01549 Hz")
#         # subsidenceRatio =Tex(f"Subsidence Ratio = 0.90721 Hz")
#
#         self.add(frequency)
